# %%
import pandas as pd

# %%
# INICIANDO COM DATAFRAME
pd.DataFrame({'Yes': [50, 105], 'No': [500, 300]})
# Out:
#    Yes   No
# 0   50  500
# 1  105  300

# %%
# NO INDEX É CRIADO AUTOMATICAMENTE
pd.DataFrame({'Name': ['Wes McKinney', 'Guido Van Rossum'], 'Number': [500, 120]})
# Out:
#                Name  Number
# 0      Wes McKinney     500
# 1  Guido Van Rossum     120

# %%
# Alterando os valores padrão dos index da linha
pd.DataFrame({
    'Column 1': [20, 50, 60],
    'Column 2': [25, 60, 20],
    'Column 3': ['hello', 'how are you', 'bye']
}, index=['Linha 1', 'Linha 2', 'Linha 3'])
# Out:
#          Column 1  Column 2     Column 3
# Linha 1        20        25        hello
# Linha 2        50        60  how are you
# Linha 3        60        20          bye

# %%
# INICIANDO SERIES
pd.Series([1, 2, 4, 6, 8, 10])
# Out:
# 0     1
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# dtype: int64

# %%
pd.Series([1, 2, 3], index=['Valor 1', 'Valor 2', 'Valor 3'], name='NOME DA LISTA')
# Out:
# Valor 1    1
# Valor 2    2
# Valor 3    3
# Name: NOME DA LISTA, dtype: int64

# %%
# INICIANDO ARQUIVO CSV
csv_titanic = pd.read_csv('titanic.csv')

# %%
# TAMANHO DO DATAFRAME --> out (linha, coluna)
csv_titanic.shape
# Out:
# (418, 11)

# %%
# MOSTRA O CABEÇALHO E ALGUNS DADOS
csv_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# ESCOLHENDO QUAL COLUNA MOSTRAR PRIMEIRO. COM ISSO NÃO CRIA UMA COLUNA CONTABILIZADA
csv_titanic_index = pd.read_csv('titanic.csv', index_col=2) # utiliza a coluna 2 como dominante
csv_titanic_index.head()
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  female
#
#                                                Age  SibSp  Parch   Ticket  \
# Name
# Kelly, Mr. James                              34.5      0      0   330911
# Wilkes, Mrs. James (Ellen Needs)              47.0      1      0   363272
# Myles, Mr. Thomas Francis                     62.0      0      0   240276
# Wirz, Mr. Albert                              27.0      0      0   315154
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1  3101298
#
# ...

# %%
csv_titanic.Name
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
csv_titanic['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
# UTILIZANDO PYTHON PARA CAPTURAR UM INDEX ESPECÍFICO
csv_titanic['Name'][417]
# Out:
# 'Peter, Master. Michael J'

# %%
# UTILIZANDO OPERADORES DO PANDAS loc e iloc para operações mais avançadas
# ILOC é utilizada em seleção baseada em índice
csv_titanic.iloc[417]
# Out:
# PassengerId                        1309
# Pclass                                3
# Name           Peter, Master. Michael J
# Sex                                male
# Age                                 NaN
# SibSp                                 1
# Parch                                 1
# Ticket                             2668
# Fare                            22.3583
# Cabin                               NaN
# Embarked                              C
# Name: 417, dtype: object

# %%
csv_titanic.iloc[417]
# Out:
# PassengerId                        1309
# Pclass                                3
# Name           Peter, Master. Michael J
# Sex                                male
# Age                                 NaN
# SibSp                                 1
# Parch                                 1
# Ticket                             2668
# Fare                            22.3583
# Cabin                               NaN
# Embarked                              C
# Name: 417, dtype: object

# %%
csv_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
csv_titanic.iloc[:2, 2:5] # (LINHA, COLUNA)
# Out:
#                                Name     Sex   Age
# 0                  Kelly, Mr. James    male  34.5
# 1  Wilkes, Mrs. James (Ellen Needs)  female  47.0

# %%
csv_titanic.iloc[-5:] # BUSCA O FINAL DO DATAFRAME
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
# LOC é utilizada em seleção baseada em valor do índice
csv_titanic.loc[417, ['Name', 'Sex']] # no index 417 eu quero o valor de nome e sexo
# Out:
# Name    Peter, Master. Michael J
# Sex                         male
# Name: 417, dtype: object

# %%
# CONFIGURANDO O ÍNDICE DOMINANTE DO DATAFRAME
csv_titanic.set_index('Name')
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  female
# ...                                                   ...     ...     ...
# Spector, Mr. Woolf                                   1305       3    male
# Oliva y Ocana, Dona. Fermina                         1306       1  female
# Saether, Mr. Simon Sivertsen                         1307       3    male
# Ware, Mr. Frederick                                  1308       3    male
# Peter, Master. Michael J                             1309       3    male
#
#                                                Age  SibSp  Parch  \
# ...

# %%
csv_titanic['Sex'][417] == 'male'
# Out:
# True

# %%
csv_titanic.Sex
csv_titanic['Sex'] # o mesmo que o de cima
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
csv_titanic.iloc[0]
# Out:
# PassengerId                 892
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
indexs = [1, 2, 4, 200, 417]
csv_titanic.loc[indexs]
# Out:
#      PassengerId  Pclass                                          Name  \
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 200         1092       3                            Murphy, Miss. Nora
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 1    female  47.0      1      0   363272   7.0000   NaN        S
# 2      male  62.0      0      0   240276   9.6875   NaN        Q
# 4    female  22.0      1      1  3101298  12.2875   NaN        S
# 200  female   NaN      0      0    36568  15.5000   NaN        Q
# 417    male   NaN      1      1     2668  22.3583   NaN        C

# %%
indexs = [1, 2, 4, 200, 417]
columns = ['Name', 'Sex', 'Ticket']

csv_titanic.loc[indexs, columns]
# Out:
#                                              Name     Sex   Ticket
# 1                Wilkes, Mrs. James (Ellen Needs)  female   363272
# 2                       Myles, Mr. Thomas Francis    male   240276
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  3101298
# 200                            Murphy, Miss. Nora  female    36568
# 417                      Peter, Master. Michael J    male     2668

# %%
csv_titanic[csv_titanic.Name == 'Myles, Mr. Thomas Francis']
# Out:
#    PassengerId  Pclass                       Name   Sex   Age  SibSp  Parch  \
# 2          894       2  Myles, Mr. Thomas Francis  male  62.0      0      0
#
#    Ticket    Fare Cabin Embarked
# 2  240276  9.6875   NaN        Q
